# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
years = range(1950, 2011, 10)
gdp = [300.2, 543.3, 1075.9, 2862.5, 5979.6, 10289.7, 14958.3]

# %%
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')

# %%
plt.title("Nominal GDP")
# Out:
# Text(0.5, 1.0, 'Nominal GDP')

# %%
plt.ylabel("Billions of $")
# Out:
# Text(0, 0.5, 'Billions of $')

# %%
plt.plot(years, gdp, color='green', marker='o', linestyle='solid')
plt.title("Nominal GDP")
plt.ylabel("Billions of $")
plt.show()

# %%
movies = ["Annie Hall", "Ben-Hur", "Casaburanca", "Ghandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]

# %%
plt.bar(range(len(movies)), num_oscars)

plt.title("My Favorite Movies")
plt.ylabel("# of Academy Awards")

plt.xticks(range(len(movies)), movies)
plt.show()

# %%
from collections import Counter
grades = [83, 95, 91, 87, 70, 0, 85, 82, 100, 67, 73, 77, 0]

histogram = Counter(min((grade // 10) * 10, 90) for grade in grades)

plt.bar(
    [x + 5 for x in histogram.keys()],
    histogram.values(),
    10,
    edgecolor=(0, 0, 0)
)

plt.axis([-5, 105, 0, 5])

plt.xticks([i * 10 for i in range(11)])
plt.xlabel("Decile")
plt.ylabel("# of Students")
plt.show()
# Out:
# Counter({80: 4, 90: 3, 70: 3, 0: 2, 60: 1})
# 80
# 90
# 70
# 0
# 60

# %%
mention = [500, 505]
years = [2017, 2018]

plt.bar(years, mention, 0.8)
plt.xticks(years)



plt.axis([2016.5, 2018.5, 0, 506])
plt.show()

# %%
variance     = [1, 2, 4, 8, 16, 32, 64, 128, 256]
bias_squared = [256, 128, 64, 32, 16, 8, 4, 2, 1]
total_error  = [x + y for x, y in zip(variance, bias_squared)]
xs = [i for i, _ in enumerate(variance)]

plt.plot(xs, variance,     'g-', label='variance')
plt.plot(xs, bias_squared, 'r_', label='bias^2')
plt.plot(xs, total_error,  'b:', label='total error')

plt.legend(loc=9) # loc=9は上部中央を指す
plt.xlabel("model complexity")
plt.xticks([])
plt.title("The Bias-Variance Tradeoff")
plt.show()

# %%
friends = [ 70,  65,  72,  63,  71,  64,  60,  64,  67]
minutes = [175, 170, 205, 120, 220, 130, 105, 145, 190]
labels =  ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i']

plt.scatter(friends, minutes)

for label, friend_count, minute_count in zip(labels, minutes, friends):
    plt.annotate(label,
                 xy=(friend_count, minute_count),
                 xytext=(5, -5),
                 textcoords='offset points')

plt.title("Daily Minutes vs. Number of Friends")
plt.xlabel("# of friends")
plt.ylabel("Daily minutes spent on the site")
plt.show()

# %%
test_1_grades = [ 99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

plt.scatter(test_1_grades, test_2_grades)
plt.title("Axes Aren't Comparable")
plt.xlabel("test 1 grade")
plt.ylabel("test 2 grade")
# plt.show()
# Out:
# Text(0, 0.5, 'test 2 grade')

# %%
test_1_grades = [ 99, 90, 85, 97, 80]
test_2_grades = [100, 85, 60, 90, 70]

plt.scatter(test_1_grades, test_2_grades)
plt.title("Axes Aren't Comparable")
plt.xlabel("test 1 grade")
plt.ylabel("test 2 grade")
plt.axis("equal")
# plt.show()
# Out:
# (79.05, 99.95, 58.0, 102.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.show()

# %%
fig = plt.figure() # empty figure with no axes

# %%
fig, ax = plt.subplots() # a figure with single axes

# %%
fig, axs = plt.subplots(2 ,2) # a figure with 2 * 2(=4 axes) grid of axes

# %%
# 1つのfigure。左にAxesひとつ。右にAxesがふたつ
fig, axs = plt.subplot_mosaic([['left', 'right-top'],
                               ['left', 'right-bottom']])

# %%
# np.matrix　ではなく　np.array　として関数に渡す
b = np.matrix([[1, 2], [3, 4]]) 
b_asarray = np.asarray(b)

# %%
np.random.seed(19680801)

data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 0),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %%
x = np.linspace(0, 2, 100)

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')

ax.plot(x, x, label='linear')
ax.plot(x, x ** 2, label='quadratic')
ax.plot(x, x ** 3, label='cubic')

ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title('simple plot')
# Out:
# Text(0.5, 1.0, 'simple plot')
